# %% [markdown]
# ### 1.What is the output of the following code?
#     nums =set([1,1,2,3,3,3,4,4])
#     print(len(nums))
# ##### Hint:Set consists of aunique element

# %% [markdown]
#  ### Answer
#     - nums contains: 1,2,3,4
#     - len(nums) : 4

# %% [markdown]
# ### 2.What will be the output?
#     d ={"john":40, "peter":45}
#     print(list(d.keys()))
#
# ##### Hint:d.keys()isthefunctionthatwillshowkeys

# %% [markdown]
# ### Answer:
#     - ['john', 'peter']

# %% [markdown]
# ### 3.A website requires a user to input a username and password to register. Write a program to check the validity of the password given by the user. Following are the criteria for checking password:
#     1. At least 1 letter between [a-z]
#     2. At least 1 number between [0-9]
#     1. At least 1 letter between [A-Z]
#     3. At least 1 character from [$#@]
#     4. Minimum length of transaction password: 6
#     5. Maximum length of transaction password: 12
#
#   #### Hint: In the case of input data being supplied to the question, it should be assumed to be a console input

# %%
import re
password=input("Enter the password: ")
print(len(password))
if re.fullmatch(r"[A-Za-z0-9$#@]{6,12}", password):
    print("password match")
else:
    print("password not match")
# Out:
# Enter the password: Abcd@123
# 8
# password match

# %% [markdown]
# ### 4.Write a for loop that prints all elements of a list and their position in the list.
#     a = [4,7,3,2,5,9]
#
# ##### Hint: Use Loop to iterate through list elements

# %%
a = [4,7,3,2,5,9]
for index,elem in enumerate(a):
    print(f"Position: {index}, Element: {elem}")
# Out:
# Position: 0, Element: 4
# Position: 1, Element: 7
# Position: 2, Element: 3
# Position: 3, Element: 2
# Position: 4, Element: 5
# Position: 5, Element: 9

# %% [markdown]
# ### 5.Please  write  a  program that accepts  a  string  from the console  and  print  the characters that have even indexes.
#
# #### Example: If the following string is given as input to the program:H1e2l3l4o5w6o7r8l9dThen, the output of the program should be:Helloworld

# %%
input_str=input("Eneter a string: ")
out_str=""
for index, elem in enumerate(input_str):
    if index%2==0:
        out_str=out_str+elem
print(out_str)
# Out:
# Eneter a string: H1e2l3l4o5w6o7r8l9d
# Helloworld

# %% [markdown]
# ### 6.Please write a program that accepts a string from the console and print it in reverse order.
# #### Example: If the following string is given as input to the program:
#     rise to vote sir
# #### Then, the output of the program should be:
#     ris etov ot esir

# %%
input_str=input("Enter a string : ")
input_str=input_str[::-1]
print(input_str)
# Out:
# Enter a string : rise to vote sir
# ris etov ot esir

# %% [markdown]
# ### 7.Please write a program that counts and prints the numbers of each character in a string input by the console.
# #### Example: If the following string is given as input to the program:
#     abcdefgabc
# #### Then, the output of the program should be
#     a,2
#     c,2
#     b,2
#     e,1
#     d,1
#     g,1
#     f,1

# %%
input_str=input("Enter a string : ")
dictionary=dict()
for i in input_str:
    if i in dictionary.keys():
        dictionary[i]=dictionary[i]+1
    else:
        dictionary[i]=1
for key in dictionary.keys():
    print(f"{key},{dictionary[key]}")
# Out:
# Enter a string : abcdefgabc
# a,2
# b,2
# c,2
# d,1
# e,1
# f,1
# g,1

# %% [markdown]
# ### 8.With   two   given   lists   [1,3,6,78,35,55]   and   [12,24,35,24,88,120,155],   write   a program to make a list whose elements are intersection of the above given lists.

# %%
list1=[1,3,6,78,35,55]
list2=[12,24,35,24,88,120,155]

intersection=[val for val in list1 if val in list2]
print(intersection)
# Out:
# [35]

# %% [markdown]
# ### 9.By using list comprehension, please write a program to print the list after removing the value 24 in [12,24,35,24,88,120,155].

# %%
list1=[12,24,35,24,88,120,155]
list1=[x for x in list1 if x!=24]
print(list1)
# Out:
# [12, 35, 88, 120, 155]

# %% [markdown]
# ### 10.By using list comprehension, please write a program to print the list after removing the 0th,4th,and 5th numbers in [12,24,35,70,88,120,155].

# %%
list1=[12,24,35,70,88,120,155]
list1=[x for index, x in enumerate (list1) if index !=0 and index !=4 and index !=5]
print(list1)
# Out:
# [24, 35, 70, 155]

# %% [markdown]
# ### 11.By using list comprehension, please write a program to print the list after removing deleted numbers that are divisible by 5 and 7 in [12,24,35,70,88,120,155].

# %%
list1=[12,24,35,70,88,120,155]
list1=[x for x in list1 if x%5!=0 or x%7!=0]
print(list1)
# Out:
# [12, 24, 88, 120, 155]

# %% [markdown]
# ### 12.Write  a  program  to  compute  1/2+2/3+3/4+...+n/n+1  with  a  given  n  input  by console (n>0).
#
# #### Example:If the following n is given as input to the program:5 Then, the output of the program should be:3.55

# %%
n=int(input("Enter a number: "))
sum=0

for i in range(n+1):
    temp=i/(i+1)
    sum=sum+temp
    

print(sum)
# Out:
# Enter a number: 5
# 3.5500000000000003

# %%
class Date:
    def __init__(self, year, month, day): #year-month-day
        self.year = year
        self.month = month
        self.day = day
        # print("init")

    #@classmethod
    def dmy(day, month, year): #day-month-year
        # print("dmy")
        poinetr1.year = year
        poinetr1.month = month
        poinetr1.day = day
        #order of return should be same as init
        return poinetr1(poinetr1.year, poinetr1.month,poinetr1.day )

    @classmethod
    def mdy(poinetr2, month, day, year): #month-day-year
        # print("mdy")
        poinetr2.year = year
        poinetr2.month = month
        poinetr2.day = day
        #order of return should be same as init
        return poinetr2(poinetr2.year, poinetr2.month, poinetr2.day)

  
   

a=Date(2016, 12, 11)
#a=Date.__init__(2016, 12, 11)
print(a.month) #2016
a.day
a.year

a

a=Date.dmy(9, 10, 2015)
a.year
a.month
a.day

b = Date(2016, 12, 11)
b.mdy(12, 10, 2019)

b=a.dmy(9, 10, 2015)
print(b.year) #2015
b.month
b.month
b.day

c=Date.mdy(7, 8, 2014)
print(c.month) #2014
# Out:
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 37
#      33 a.year
#      35 a
# ---> 37 a=a.dmy(9, 10, 2015)
#      38 a.year
#      39 a.month
#
# TypeError: Date.dmy() takes 3 positional arguments but 4 were given

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3, venn3_circles
from matplotlib_venn import venn2, venn2_circles

set1 = set(['A', 'B', 'C', 'D'])
set2 = set(['B', 'C', 'D', 'E'])

v = venn2([set1, set2], ('Set1', 'Set2'))

v.get_label_by_id('10').set_text('\n A')
v.get_label_by_id('01').set_text('\n E')
v.get_label_by_id('11').set_text('\n \nB \nC \nD')
plt.show()

# %%
#pip install matplotlib_venn

# %%
from venn import venn

set1 = set(['A', 'B', 'C', 'D'])
set2 = set(['B', 'C', 'D', 'E'])

set3 = set(['A', 'F', 'C', 'D'])
set4 = set(['B', 'G', 'D', 'E'])

sets = {
    "labels[0]": set1,
    "labels[1]": set2,
    "labels[2]": set3,
    "labels[3]": set4
}
fig, ax = plt.subplots(1, figsize=(16,12))
venn(sets, ax=ax)
plt.legend(labels[:-2], ncol=6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [55], line 17
#      15 fig, ax = plt.subplots(1, figsize=(16,12))
#      16 venn(sets, ax=ax)
# ---> 17 plt.legend(labels[:-2], ncol=6)
#
# NameError: name 'labels' is not defined

# %%
pip install venn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting venn
#   Downloading venn-0.1.3.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\736944\appdata\roaming\python\python310\site-packages (from venn) (3.6.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (1.23.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\736944\appdata\roaming\python\python310\site-packages (from matplotlib->venn) (1.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\736944\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->venn) (1.16.0)
# Using legacy 'setup.py install' for venn, since package 'wheel' is not installed.
# Installing collected packages: venn
#   Running setup.py install for venn: started
#   Running setup.py install for venn: finished with status 'done'
# Successfully installed venn-0.1.3
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
##Overriding method
class Parent: # define parent class
    
    def __init__(self, base):
        self.base=base
    
    def printBase(self):
        print(self.base)

    
class Child(Parent): # define child class
    def __init__(self, base, child):
        Parent.__init__(self, base)
        self.child=child
    
    def printChild(self):
        print(self.child)
        
        

    
c = Child("base Param", "child Param")   # instance of child
c.printBase() # child calls overridden method
c.printChild()

# p = Parent()   # instance of parent
# p.myMethod()



        
#     def mybaseMethod(self):
#         print("Calling parent method")
#         def myMethod(self, child):
#         print("Calling child method")
# Out:
# base Param
# child Param
